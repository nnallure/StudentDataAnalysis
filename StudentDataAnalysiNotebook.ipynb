# %%
import pandas as pd

data = {"name": ["Bill", "Tom", "Tim", "John", "Alex", "Vanessa", "Kate"],
        "math score": [90, 90, 80, 70, 65, 10, 50],
        "sport": ["Wrestling", "Football", "Skiing", "Soccer", "Soccer", "Soccer", "Soccer"],
        "gender": ["M", "M", "M", "M", "F", "F", "F"]}

df_data = pd.DataFrame(data)
print(df_data.shape)
# Out:
# (7, 4)

# %%
#adding column
df_data["major"] = ["BA", "BA", "FIN", "FIN", "MKTG", "MKTG", "MGT"]

# %%
#deleting column
del df_data["gender"]

# %%
#change index
df_data.index = ["one", "two", "three", "four", "five", "six", "seven", ]

# %%
#create a column based on condition
df_data["pass"] = df_data["math score"] >= 85

# %%
#summary statistics
df_data.describe()
# Out:
#        math score
# count    7.000000
# mean    65.000000
# std     28.136572
# min     10.000000
# 25%     57.500000
# 50%     70.000000
# 75%     85.000000
# max     90.000000

# %%
chem_phy = {"name":["Bill", "Tom", "Tim", "John", "Alex", "Vanessa", "Kate"],
            "chem score": [50, 60, 70, 80, 65, 80, 90],
            "phys_score": [55, 65, 75, 85, 70, 85, 95]}

df_data_2 = pd.DataFrame(chem_phy)

# %%
df_data
# Out:
#           name  math score      sport major   pass
# one       Bill          90  Wrestling    BA   True
# two        Tom          90   Football    BA   True
# three      Tim          80     Skiing   FIN  False
# four      John          70     Soccer   FIN  False
# five      Alex          65     Soccer  MKTG  False
# six    Vanessa          10     Soccer  MKTG  False
# seven     Kate          50     Soccer   MGT  False

# %%
df_data_2
# Out:
#       name  chem score  phys_score
# 0     Bill          50          55
# 1      Tom          60          65
# 2      Tim          70          75
# 3     John          80          85
# 4     Alex          65          70
# 5  Vanessa          80          85
# 6     Kate          90          95

# %%
df_merge = pd.merge(df_data, df_data_2, on = "name", how = "left")

# %%
df_merge = df_merge.rename(columns = {"phys_score": "phys score"})

# %%
df_merge["total score"] = df_merge["math score"] + df_merge["chem score"] + df_merge["phys score"]

# %%
df_merge[(df_merge["math score"]>=75) & (df_merge["chem score"]>=70)]
# Out:
#   name  math score   sport major   pass  chem score  phys score  total score
# 2  Tim          80  Skiing   FIN  False          70          75          225

# %%
df_merge.sort_values(by = ["name"])
# Out:
#       name  math score      sport major   pass  chem score  phys score  \
# 4     Alex          65     Soccer  MKTG  False          65          70
# 0     Bill          90  Wrestling    BA   True          50          55
# 3     John          70     Soccer   FIN  False          80          85
# 6     Kate          50     Soccer   MGT  False          90          95
# 2      Tim          80     Skiing   FIN  False          70          75
# 1      Tom          90   Football    BA   True          60          65
# 5  Vanessa          10     Soccer  MKTG  False          80          85
#
#    total score
# 4          200
# 0          195
# 3          235
# 6          235
# 2          225
# 1          215
# 5          175
